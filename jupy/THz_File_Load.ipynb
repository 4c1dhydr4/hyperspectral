# %%
import scipy.io
import pandas as pd
from matplotlib import pyplot as plt
plt.show()

# %%
mat = scipy.io.loadmat('D:\\Documentos\\LUIS AUGUSTO\\paper\\sample161.mat')
mat['sample161'].shape
# Out:
# (2050, 5434)

# %%
data = pd.DataFrame(mat['sample161'])

# %%
p = (300,1000)
data.iloc[p[0]:p[1],3].plot()
data.iloc[p[0]:p[1],5433].plot()

# %%
data2 = pd.read_csv("D:\Documentos\LUIS AUGUSTO\paper\data_polyscan\img_2147483645_data.txt", sep='\t', header=None)

# %%
data2.shape
# Out:
# (2050, 9667)

# %%
data2.iloc[p[0]:p[1],3].plot()
data2.iloc[p[0]:p[1],9666].plot()

# %%
data3 = pd.read_csv("D:\Documentos\LUIS AUGUSTO\paper\data_polyscan\img_2147483646_data.txt", sep='\t', header=None)
data3.shape
# Out:
# (2050, 11192)

# %%
data3.iloc[p[0]:p[1],3].plot()
data3.iloc[p[0]:p[1],11191].plot()

# %% [markdown]
# ## sample161.mat =  img_2147483647_data.txt

# %%
data4 = pd.read_csv("D:\Documentos\LUIS AUGUSTO\paper\data_polyscan\img_2147483647_data.txt", sep='\t', header=None)
data4.shape
# Out:
# (2050, 5434)

# %%
data4.iloc[p[0]:p[1],3].plot()
data4.iloc[p[0]:p[1],5433].plot()
