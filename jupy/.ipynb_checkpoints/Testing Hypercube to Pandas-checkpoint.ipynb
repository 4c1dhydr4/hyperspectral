# %% [markdown]
# # Testing de Lectura de Imágenes Hiperspectrales

# %%
import pandas as pd
import os
from matplotlib import pyplot as plt
from spectral import *

# %%
PROJ_DIR = os.path.dirname(os.getcwd())
SAMPLES_DIR = os.path.join(PROJ_DIR, 'samples')
SAMPLE_FILE = SAMPLES_DIR + '\\HARC000.bil.hdr'
SAMPLE_FILE
# Out:
# 'C:\\Developer\\THZ\\samples\\HARC000.bil.hdr'

# %% [markdown]
# ### Abrimos la imágen hiperspectral

# %%
SAMPLE = open_image(SAMPLE_FILE)
SAMPLE
# Out:
# 	Data Source:   'C:\Developer\THZ\samples\HARC000.bil'
# 	# Rows:            173
# 	# Samples:         207
# 	# Bands:           150
# 	Interleave:        BIL
# 	Quantization:  16 bits
# 	Data format:    uint16

# %% [markdown]
# ### Cargamos el conjunto de datos de la Imágen en Memoria

# %%
s = SAMPLE.load()
# Out:
# c:\virtualenvs\thz\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ### Convertimos el hipercubo en un arreglo de datos Numpy

# %%
a = s.asarray()

# %% [markdown]
# ### Ploteamos la firma espectral del primer Píxel

# %%
plt.plot(a[0,0,:])
plt.plot(a[0,1,:])
plt.plot(a[0,2,:])
plt.plot(a[0,3,:])
plt.plot(a[0,4,:])
plt.plot(a[0,5,:])
plt.plot(a[0,6,:])
plt.plot(a[0,7,:])
plt.plot(a[0,8,:])
plt.plot(a[0,9,:])
plt.plot(a[0,10,:])
plt.xlabel('Banda')
plt.ylabel('Reflectancia del Pixel')
plt.show()
